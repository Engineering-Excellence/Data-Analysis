# %%
import time
import warnings

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

warnings.filterwarnings(action='ignore')

# %%
option = Options()
option.add_argument('--window-size=1600,900')
driver = webdriver.Chrome('./chromedriver', options=option)
driver.implicitly_wait(5)

driver.get('https://comic.naver.com/comment/comment?titleId=790713&no=95')
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
reviews = soup.select('span.u_cbox_contents')

# 베댓의 개수 만큼 반복한다.
for i in range(len(reviews[:])):
    print(f'{i + 1:02d}번째 베댓: {reviews[i].text}')

    # 베댓 답글을 연다.
    path = f'//*[@id="cbox_module_wai_u_cbox_content_wrap_tabpanel"]/ul/li[{i + 1}]/div[1]/div/div[5]/a'
    driver.find_element(By.XPATH, path).click()
    time.sleep(0.5)

    # 베댓 1번째 답글 페이지를 읽는다.
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    replies = soup.select('div.u_cbox_reply_area span.u_cbox_contents')
    # if len(replies) != 0:
    #     print(f'{i + 1:02d}번째 베댓 답글 개수: {len(replies)}개')

    # 베댓 1번째 답글 페이지에 답글이 있으면 출력한다.
    if len(replies) == 0:
        print('답글 없음')
    else:
        for reply in replies:
            print(f'→ {reply.text}')

    # 베댓 1번째 답글 페이지를 제외한 나머지 답글 페이지 개수를 얻어온다.
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    replyPage = soup.select('.u_cbox_reply_area .u_cbox_page')
    # print(f'베댓 답글 페이지 개수: {len(replyPage)}개')

    # 1번째 베댓 페이지의 답글은 읽어왔으므로 2번째 베댓 답글 페이지부터 마지막 베댓 답글 페이지까지 반복한다.
    for j in range(1, len(replyPage)):
        # 다음에 읽을 베댓 답글을 연다.
        driver.find_element(By.CSS_SELECTOR, 
            f'#cbox_module_wai_u_cbox_content_wrap_tabpanel div.u_cbox_paginate > div > a:nth-child({str(j + 3)})').click()
        time.sleep(0.5)

        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        replies = soup.select('div.u_cbox_reply_area span.u_cbox_contents')
        for reply in replies:
            print(f'→ {reply.text}')
    print()

    # 베댓 답글을 닫는다.
    driver.find_element(By.XPATH, path).click()
    time.sleep(0.5)
# Out:
# 01번째 베댓: 동기들도 눈치까고 노린거임ㅋㅋㅋ딱 보면 모르나
# → 이런거 특 : 당사자만 모르고 주위는 다 ~~~~~ 앎
# → 저 뼝아리가 그런 눈치가...
# → 노렸다고 해도 이건 트롤인뎈ㅋㅋㅋㅋㅋㅋㅋ 저 시대에도 카톡고백은 금기였는걸...!
# → 내가 제일로 사랑하는 자식이 누군지 니 모리나!!!! 순양이다 ㅉ
# → 작가님: (충격)
#
# 02번째 베댓: 우와 작가님 너무 옛날 에피소드 같아요
# → ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# → 악ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# → 나 초딩때네 ㄷ ㄷ
# → ㅋㅋㅋㅋㅋㅋㅋㅋ
# → 놀리지마요
# → ㅋㅋㅋㅋㅋ
# → 그래도 재밌어요 히히
# → ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 뜻밖의 광역기 (마상)
# → 와 애x팡 대체 저게 얼마나 예전이야ㅋㅋㅋㅋㅋㅋㅋㅋ 초딩때 엄마폰으로 하다가 하트로 엄마카톡 도배된것도 기억나네
# → ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 그래도 작가님이 저보단 어리신것같아요... 우왕
# → 이게 그렇게나 유물이 된건가요ㅜㅜ 엊그제같은데
# → 이 나쁜 사람들 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# → 애니팡때인가....
# → ㅋㅋㅋㅋㅋㅋㅋㅋㅋ못된 것
# → 다들 너무해ㅜㅜㅠ(이하 작가님 또래..)
# → 아.. 난 대딩때 유행했는데,,
# → ?? 애니팡을 엄마폰으로 했다고..???.......내 폰이 아니고???
# → 나도 대학생때 애니팡했는데....늙은거구나ㅠ
# → 이렇게 멕이네..
# → 저도 이번글보면서 예전 추억에 젖었어요…올해로 서른… 저 대학생때 애니팡 완전 난리였는데
# → 생각해보니 그러네 ㅋㅋㅋ 나 학생때인데
# → 와 하트팡 개오랜만이다ㅋㅋㅋㅋㅋㅋㅋ
# → ㅁㅊ ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# → 애니팡이였나..ㅋㅋㅋㅋㅋ
# → ㅋㅋㅋㅋㅋㅋㅋㅋ애니팡 진짜 추억이네요ㅋㅋㅋㅋㅋ
# → 학생 댓글내려
# → 엄마 애니팡하는 거 구경했던 초딩이 대학 새내기가 되엇어요..
# → 예...? 나 사회초년생때 애니팡했는데... 흐뭇하게 웃다가 날벼락
#
# 03번째 베댓: 아니 조교님한테 게임하트도 아니고 진짜로 냅다 하트를 보낸거예요?ㅋㅋㅋㅋㅋㅋㅋㅋ
# → 시그널 보내 시그널 보내 찌릿 찌릿 찌릿 찌릿 ㅉ
# → 용감하다!!!
# → 아 그러네ㅋㅋㅋㅋ
#
# 04번째 베댓: 작가님 피셜 저 욕쟁이는 삼X전자 들어갔답니다
# → ????
# → 작가님 인스타에 있어요
# → 조별과제 팀원들 근황삼X전자, 의사, 해외 박사과정, 웹툰작가..
# 다들 성공하심
# → 하긴 Y대 공대인데...
# → 엥 근데 공대 아녔음?? 공대출신 의사가 있을 수 있나 ㄷㄷ
# → ㄴ 의전원이요
# → ㄴ아니면 새내기때 조별과제였으니 반수였을수도
# → 진짜로???? 와우..
# → 그리고 작가님피셜 공대생활중 만났던 가장착한 사람 top3에 드시는분이라했어요 ㅋㅋ
# → 의사가 아니라 약사 아니었나??
# → ㄴ약사는 근똥이요! 초록이 중에 한명은 의사래요 (출처 작가님 인스타)
# → 약사는 약학대학 들어가야 하는거 아닌가
# → 근똥이 피트쳐서 약대드감
#
# 05번째 베댓: = 나 퇴근하고 싶으니까 얼른 끝내라
# 답글 없음
#
# 06번째 베댓: 없던 정도 생기겠네요
# 답글 없음
#
# 07번째 베댓: 어머어머어머 눈 커진거봐 고미 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 답글 없음
#
# 08번째 베댓: 살짝 노린감이 있네ㅋㅋㅋ말투에 따라서 장난식으로 할수도 있고 호감표현으로 할수도 있는데 왠지 후자였을것같음
# 답글 없음
#
# 09번째 베댓: 초록이 이쯤되면 캐릭터 하나 받아야한다
# → 사악한 쑥떡 같아요
# → 초록색 영구결번 가죠
# → 착쁜애래요
#
# 10번째 베댓: 쟤 저번 조별과제부터 계속 욕하면서 도와줄 거 다 도와줌ㅋㅋㅋㅋㅋㅋ ㅈㄴ 츤데레
# → 작가님이 저분 지금까지 만났던 사람들중 친절함 탑쓰리에 들어간다하셨어요 ㅋㅋㅋㅋ
# → 저렇게 초록 얼굴인데 다 기억하는게 신기방기
#
# 11번째 베댓: 여기서 조교님이 잘 생겼다는걸 알 수 있습니다 대충 이렇게 생겼으면 시도하지 마세요 짤...
# → 왜 못생겨도 잘생긴사람한테 대쉬할수도 있지
# → ㄴ 뭔 개소리야
# → ㄴㄴ할 수 없어
# → 시도는 해봐도 되는거 아님? 실패하면 그걸로 끝내면 되지 왜이리 세상이 각박하냐
# → ㄴ 독자층이 독자층이다보니 아무래도...
# → ??? 그 사람에게는 상처가 될 수 있잖아요.
# → 고백으로 혼내주기ㅋㅋ
#
# 12번째 베댓: 교수님이랑 같이 술약속이 잡혀있거든
# → 입틀막..
# → 오 세상에 맙소사..
#
# 13번째 베댓: 저거 보면 남는사람들만 남음ㅋㅋㅋㅋ
# 답글 없음
#
# 14번째 베댓: 와 작가님 저 저거 초딩때 했어요
# → 하!
# → 충격적이다..
# → 그..그만..
# → 헐 저도 초딩때 유행했어요..대충 한 초중딩때 같긴했는데 찾아보니까 초딩때 나왔네요
# → 저도 초딩때...ㅋㅋㅋㅋ
# → 저도 초딩... 심지어 고학년때는 이미 옛날게임되있었음
# → 작가님 아무리 늦어도 13학번 이하11이나 12가 가장 유력함
# → 카카오톡 안드로이드 pc버전이 출시되기 전에 나온 게임이네요.....
#
# 15번째 베댓: 교수가 시킨 거 처리하기도 바쁜데 무슨 술임ㅋㅋ
# 답글 없음
